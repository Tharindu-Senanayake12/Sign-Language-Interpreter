# %%
import cv2      # OpenCV
import os       # helps to work with file paths
import time     # to add delays
import uuid     # to generate unique(image) filenames

# %%
IMAGES_PATH = 'Tensorflow/workspace/images/collectedimages'

labels = ['hello', 'thanks', 'yes', 'no', 'iloveyou']
number_imgs = 15

# %% [markdown]
# # Collect images for Signs

# %%
for label in labels:
    # !mkdir {'Tensorflow\workspace\images\collectedimages\\' + label}
    cap = cv2.VideoCapture(0)   # 0 is usually the built-in webcam
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH, label, label + '.' + '{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)
        
        if cv2.waitKey(1) & 0xFF == ord('q'): 
            break
    cap.release()
# Out:
# Collecting images for hello
# Collecting images for thanks
# Collecting images for yes
# Collecting images for no
# Collecting images for iloveyou
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Requirement already satisfied: pyqt5 in c:\users\thari\appdata\local\programs\python\python310\lib\site-packages (5.15.11)
# Collecting lxml
#   Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in c:\users\thari\appdata\local\programs\python\python310\lib\site-packages (from pyqt5) (12.17.2)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in c:\users\thari\appdata\local\programs\python\python310\lib\site-packages (from pyqt5) (5.15.2)
# Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.0 MB 4.2 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.0 MB 4.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 4.5 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 4.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 2.5 MB/s  0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2

# %%
# !pip list
# Out:
# Package               Version
# --------------------- -----------
# absl-py               2.3.1
# asttokens             3.0.0
# attrs                 25.4.0
# cffi                  2.0.0
# colorama              0.4.6
# comm                  0.2.3
# comtypes              1.4.13
# contourpy             1.3.2
# cupy-cuda12x          13.6.0
# cycler                0.12.1
# debugpy               1.8.17
# decorator             5.2.1
# exceptiongroup        1.3.0
# executing             2.2.1
# fastrlock             0.8.3
# flatbuffers           25.9.23
# fonttools             4.60.1
# ipykernel             7.1.0
# ipython               8.37.0
# jax                   0.6.2
# jaxlib                0.6.2
# jedi                  0.19.2
# jupyter_client        8.6.3
# jupyter_core          5.9.1
# kiwisolver            1.4.9
# llvmlite              0.46.0
# lxml                  6.0.2
# matplotlib            3.10.7
# matplotlib-inline     0.2.1
# mediapipe             0.10.21
# ml_dtypes             0.5.3
# mpi4py                4.1.1
# nest-asyncio          1.6.0
# numba                 0.63.1
# numpy                 1.26.4
# opencv-contrib-python 4.11.0.86
# opencv-python         4.11.0.86
# opt_einsum            3.4.0
# packaging             25.0
# parso                 0.8.5
# pillow                12.0.0
# pip                   25.3
# platformdirs          4.5.0
# prompt_toolkit        3.0.52
# protobuf              4.25.8
# psutil                7.1.3
# pure_eval             0.2.3
# pycparser             2.23
# Pygments              2.19.2
# pyparsing             3.2.5
# pypiwin32             223
# PyQt5                 5.15.11
# PyQt5-Qt5             5.15.2
# PyQt5_sip             12.17.2
# python-dateutil       2.9.0.post0
# pyttsx3               2.99
# pywin32               311
# pyzmq                 27.1.0
# scipy                 1.15.3
# sentencepiece         0.2.1
# setuptools            57.4.0
# six                   1.17.0
# sounddevice           0.5.3
# stack-data            0.6.3
# tornado               6.5.2
# traitlets             5.14.3
# ttkbootstrap          1.19.0
# typing_extensions     4.15.0
# wcwidth               0.2.14

# %%
LABELIMG_PATH = os.path.join('Tensorflow','labelImg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}
# Out:
# Cloning into 'Tensorflow\labelImg'...

# %%
if os.name == 'posix':
    # !cd {LABELIMG_PATH} && make qt5py3
if os.name == 'nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %% [markdown]
# # Run LabelImg Package
